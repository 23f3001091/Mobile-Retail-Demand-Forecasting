# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("cleaned_sales_data.xlsx", header=1)

# %%
corr_df = df[['Quantity', 'Unit Price', 'Total']]
corr_df.head()
# Out:
#    Quantity  Unit Price     Total
# 0       1.0    18000.00  18000.00
# 1       1.0    16798.91  16798.91
# 2       1.0    14000.00  14000.00
# 3       1.0    11999.00  11999.00
# 4       1.0      150.00    150.00

# %%
corr_matrix = corr_df.corr()
corr_matrix
# Out:
#             Quantity  Unit Price     Total
# Quantity    1.000000   -0.234525 -0.207695
# Unit Price -0.234525    1.000000  0.997587
# Total      -0.207695    0.997587  1.000000

# %%
plt.figure(figsize=(6, 4))

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap='coolwarm',
    fmt=".2f",
    linewidths=0.5
)

plt.title("Correlation Heatmap: Quantity, Unit Price & Revenue")
plt.tight_layout()
plt.savefig("correlation_heatmap.png", dpi=300)
plt.show()
